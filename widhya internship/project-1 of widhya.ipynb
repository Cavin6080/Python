# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv")

# %%
dataset.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
dataset.dtypes
# Out:
# Sno                          int64
# Date                        object
# State/UnionTerritory        object
# ConfirmedIndianNational      int64
# ConfirmedForeignNational     int64
# Cured                        int64
# Deaths                       int64
# dtype: object

# %%
missing_data = dataset.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Sno
# False    270
# Name: Sno, dtype: int64
#
# Date
# False    270
# Name: Date, dtype: int64
#
# State/UnionTerritory
# False    270
# Name: State/UnionTerritory, dtype: int64
#
# ConfirmedIndianNational
# False    270
# Name: ConfirmedIndianNational, dtype: int64
#
# ConfirmedForeignNational
# False    270
# Name: ConfirmedForeignNational, dtype: int64
#
# Cured
# False    270
# Name: Cured, dtype: int64
#
# Deaths
# False    270
# Name: Deaths, dtype: int64

# %%
dataset.drop(["Sno"],axis=1,inplace=True)

# %%
grp = dataset.groupby("Date",sort=False).count()

# %%
df = pd.DataFrame(grp)

# %%
df
# Out:
#           State/UnionTerritory  ConfirmedIndianNational  \
# Date
# 30/01/20                     1                        1
# 31/01/20                     1                        1
# 01/02/20                     1                        1
# 02/02/20                     1                        1
# 03/02/20                     1                        1
# 04/02/20                     1                        1
# 05/02/20                     1                        1
# 06/02/20                     1                        1
# 07/02/20                     1                        1
# 08/02/20                     1                        1
# 09/02/20                     1                        1
# 10/02/20                     1                        1
# 11/02/20                     1                        1
# 12/02/20                     1                        1
# 13/02/20                     1                        1
# 14/02/20                     1                        1
# ...

# %%
grp1 = dataset.groupby('Date',sort=False).sum()

# %%
df1 = pd.DataFrame(grp1)

# %%
df1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
sum_row = df1.sum(axis=1)
sum_row
# Out:
# Date
# 30/01/20      1
# 31/01/20      1
# 01/02/20      2
# 02/02/20      3
# 03/02/20      3
# 04/02/20      3
# 05/02/20      3
# 06/02/20      3
# 07/02/20      3
# 08/02/20      3
# 09/02/20      3
# 10/02/20      3
# 11/02/20      3
# 12/02/20      3
# 13/02/20      3
# 14/02/20      3
# 15/02/20      3
# 16/02/20      3
# 17/02/20      3
# 18/02/20      3
# 19/02/20      3
# 20/02/20      3
# 21/02/20      3
# 22/02/20      3
# 23/02/20      3
# 24/02/20      3
# 25/02/20      3
# 26/02/20      3
# 27/02/20      3
# 28/02/20      3
# 29/02/20      3
# 01/03/20      3
# 02/03/20      5
# 03/03/20      9
# 04/03/20     31
# 05/03/20     33
# 06/03/20     34
# 07/03/20     37
# 08/03/20     42
# 09/03/20     49
# 10/03/20     61
# 11/03/20     63
# 12/03/20     77
# 13/03/20     85
# 14/03/20     96
# 15/03/20    125
# 16/03/20    129
# 17/03/20    154
# 18/03/20    168
# 19/03/20    197
# 20/03/20    250
# 21/03/20    310
# dtype: int64

# %%
data=[["30/01/20",1],["31/01/20",1],["01/02/20",2],["02/02/20",3],["03/02/20",3],["04/02/20",3],["05/02/20",3],["06/02/20",3],["07/02/20",3],["08/02/20",3],["09/02/20",3],["10/02/20",3],["11/02/20",3],
      ["12/02/20",3],["13/02/20",3],["14/02/20",3],["15/02/20",3],["16/02/20",3],["17/02/20",3],["18/02/20",3],["19/02/20",3],["20/02/20",3],["21/02/20",3],["22/02/20",3],["23/02/20",3],["24/02/20",3],
      ["25/02/20",3],["26/02/20",3],["27/02/20",3],["28/02/20",3],["29/02/20",3],["01/03/20",3],["02/03/20",5],["03/03/20",9],["04/03/20",31],["05/03/20",33],["06/03/20",34],["07/03/20",37],["08/03/20",42],
      ["09/03/20",49],["10/03/20",61],["11/03/20",63],["12/03/20",77],["13/03/20",85],["14/03/20",96],["15/03/20",125],["16/03/20",129],["17/03/20",154],["18/03/20",168],["19/03/20",197],["20/03/20",250],["21/03/20",310]]

# %%
df2 = pd.DataFrame(data, columns = ['Date', 'Cases'])

# %%
df2
# Out:
#         Date  Cases
# 0   30/01/20      1
# 1   31/01/20      1
# 2   01/02/20      2
# 3   02/02/20      3
# 4   03/02/20      3
# 5   04/02/20      3
# 6   05/02/20      3
# 7   06/02/20      3
# 8   07/02/20      3
# 9   08/02/20      3
# 10  09/02/20      3
# 11  10/02/20      3
# 12  11/02/20      3
# 13  12/02/20      3
# 14  13/02/20      3
# 15  14/02/20      3
# 16  15/02/20      3
# 17  16/02/20      3
# 18  17/02/20      3
# 19  18/02/20      3
# 20  19/02/20      3
# 21  20/02/20      3
# 22  21/02/20      3
# 23  22/02/20      3
# 24  23/02/20      3
# 25  24/02/20      3
# 26  25/02/20      3
# 27  26/02/20      3
# 28  27/02/20      3
# 29  28/02/20      3
# 30  29/02/20      3
# 31  01/03/20      3
# 32  02/03/20      5
# 33  03/03/20      9
# 34  04/03/20     31
# 35  05/03/20     33
# 36  06/03/20     34
# 37  07/03/20     37
# 38  08/03/20     42
# 39  09/03/20     49
# 40  10/03/20     61
# 41  11/03/20     63
# 42  12/03/20     77
# 43  13/03/20     85
# ...

# %%
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
ax.set_xlabel("Date")
plt.xticks(rotation = 50)
#ax.tick_params(axis="x",bottom=False,labelbottom=False)
ax.set_ylabel("Cases")
ax.plot(df2["Date"],
        df2["Cases"])
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
Date = df2["Date"]
Cases = df2["Cases"]
sns.barplot(x = Date,
           y = Cases,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.show()
